# %%
from content_core import extract_content

content = await extract_content({"url": "https://www.youtube.com/watch?v=jJl82-vQdok"})
# Out:
# 2025-06-14 09:25:57.707 | WARNING  | content_core.processors.youtube:extract_youtube_transcript:175 - Extracting transcript from URL: https://www.youtube.com/watch?v=jJl82-vQdok

# %%
content
# Out:
# ProcessSourceOutput(title="⚡Production solaire, autoconsommation, panneau sur prise Sunology: mon avis et retour d'expérience", file_path='', url='https://www.youtube.com/watch?v=jJl82-vQdok', source_type='url', identified_type='youtube', identified_provider='', metadata={'video_id': 'jJl82-vQdok', 'transcript': "1\n00:00:00,080 --> 00:00:03,280\nbonjour à tous et bienvenue dans un\n\n2\n00:00:01,319 --> 00:00:04,920\nnouvel épisode de la pouseetech vous\n\n3\n00:00:03,280 --> 00:00:06,759\navez déjà certainement vu certaines de\n\n4\n00:00:04,920 --> 00:00:09,000\nnos vidéos sur des batteries et ben\n\n5\n00:00:06,759 --> 00:00:11,320\naujourd'hui on va s'intéressé à l'autre\n\n6\n00:00:09,000 --> 00:00:13,519\nphase de la pièce l'énergie solaire si\n\n7\n00:00:11,320 --> 00:00:15,280\nvous souhaitez débuter dans la\n\n8\n00:00:13,519 --> 00:00:16,680\nproduction d'énergie solaire si vous\n\n9\n00:00:15,280 --> 00:00:18,320\nêtes curieux de savoir comment ça se\n\n10\n00:00:16,680 -
# ...
